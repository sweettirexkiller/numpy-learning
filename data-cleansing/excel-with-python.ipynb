# %%
import pandas as pd
import numpy as np 
import xlrd

# %%
vivoidship = pd.read_excel('WypadkiwgwojewodztwIX2016.xls', sheet='ogółem',skiprows=2,skip_footer=1)
vivoidship
# Out:
#     Unnamed: 0                                         Unnamed: 1  ciężki  \
# 0            1                                        Przedszkole      10
# 1            3                                  Szkoła podstawowa      62
# 2            4                                          Gimnazjum      53
# 3           13                         Zasadnicza szkoła zawodowa       0
# 4           14                            Liceum ogólnokształcące      13
# 5           16                                          Technikum       6
# 6           19               Szkoła policealna (ponadgimnazjalna)       0
# 7           20  Szkoła specjalna przysposabiająca do pracy dla...       1
# 8           21  Sześcioletnia ogólnokształcąca szkoła muzyczna...       0
# 9           22            Sześcioletnia szkoła muzyczna I stopnia       0
# 10          23             Czteroletnia szkoła muzyczna I stopnia       0
# 11          24  Sześcioletnia ogólnokształcąca szkoła muzyczna...       0
# ...

# %%
vivoidship1 = pd.read_excel('WypadkiwgwojewodztwIX2016.xls',\
                            sheet_name=1, skiprows=2,\
                            usecols=[1,3,4,5,6],\
                            index_col=[1,0],skip_footer=1)
vivoidship1= vivoidship1.swaplevel(1,axis=0)
vivoidship1.sortlevel(0,axis=0, inplace=True)
vivoidship1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: sortlevel is deprecated, use sort_index(level= ...)
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                        ciężki  \
#                                              Unnamed: 0
# Bednarska Szkoła Realna                      WOJ. MAZOWIECKIE               0
# Bursa                                        WOJ. DOLNOŚLĄSKIE              0
#                                              WOJ. KUJAWSKO-POMORSKIE        0
#                                              WOJ. LUBELSKIE                 0
#                                              WOJ. MAŁOPOLSKIE               0
#                                              WOJ. PODLASKIE                 0
#                                              WOJ. POMORSKIE                 0
# ...

# %%
czesciCiala = pd.read_excel("WypadkiwgwojewodztwIX2016.xls", sheet_name=6, usecols=[1,3,4,5,6], index_col=[0,1], header=[2,3])
czesciCiala
# Out:
#                                                                            ciężki  \
#                                                                             głowa
# WOJ. DOLNOŚLĄSKIE       Przedszkole                                             0
#                         Szkoła podstawowa                                       2
#                         Gimnazjum                                               1
#                         Zasadnicza szkoła zawodowa                              0
#                         Liceum ogólnokształcące                                 1
#                         Technikum                                               0
#                         Szkoła policealna (ponadgimnazjalna)                    0
#                         Szkoła specjalna przysposabiająca do pracy dla ...      0
#                         Sześcioletnia ogólnokształcąca szkoła muzyczna ...      0
# ...
